# %% [markdown]
# # FUSRGG Simuation

# %%
import MDAnalysis as mda
from my_lib import Analysis

# %%
uni = mda.Universe("top.pdb", "sim.dcd")
uni
# Out:
# /home/sujaly/anaconda3/envs/MDAnalysis/lib/python3.13/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# <Universe with 34 atoms>

# %%
protein_analysis = Analysis(uni)

# %% [markdown]
# Contact map of initial geometry

# %%
first_frame = 0
protein_analysis.set_frame(first_frame)
protein_analysis.genrate_contact_map()

# %% [markdown]
# Contact map at the middle of simualtion

# %%
mid_frame = int(len(uni.trajectory)/2)
protein_analysis.set_frame(mid_frame)
protein_analysis.genrate_contact_map()

# %% [markdown]
# Contact map of final geometry

# %%
last_frame = len(uni.trajectory) - 1
protein_analysis.set_frame(last_frame)
protein_analysis.genrate_contact_map()

# %% [markdown]
# Plot of radius of gyration with time

# %%
protein_analysis.plot_radius_of_gyration()

# %% [markdown]
# Distribution of radius of gyration

# %%
protein_analysis.probability_rgyr()
